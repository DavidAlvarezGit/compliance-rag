# %%
import pandas as pd
df = pd.read_parquet("chunks.parquet")

print(df.head(10))
print("Total chunks:", len(df))
print("Avg length:", df["chunk_text"].str.len().mean())
# Out:
#           doc_id doc_type  year  issue language  page_start  page_end  \
# 0  QB_2020_Q1_FR       QB  2020      1       FR           5         7
# 1  QB_2020_Q1_FR       QB  2020      1       FR           7         8
# 2  QB_2020_Q1_FR       QB  2020      1       FR           8         9
# 3  QB_2020_Q1_FR       QB  2020      1       FR           9        10
# 4  QB_2020_Q1_FR       QB  2020      1       FR          10        11
# 5  QB_2020_Q1_FR       QB  2020      1       FR          11        12
# 6  QB_2020_Q1_FR       QB  2020      1       FR          12        13
# 7  QB_2020_Q1_FR       QB  2020      1       FR          13        14
# 8  QB_2020_Q1_FR       QB  2020      1       FR          14        15
# 9  QB_2020_Q1_FR       QB  2020      1       FR          15        16
#
#                                           chunk_text
# 0  Table des matières\\nPage\n\t \t Rapport sur...
# 1  1 \nDécision de politique \nmonétaire du  \n19...
# ...
